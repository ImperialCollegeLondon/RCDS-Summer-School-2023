# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd

# %%
#Define coordinates of where we want to center our map
boulder_coords = [40.015, -105.2705]

#Create the map
my_map = folium.Map(location = boulder_coords, zoom_start = 13)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06f2b28d759e8354f2a33898116eb6b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06f2b28d759e8354f2a33898116eb6b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06f2b28d759e8354f2a33898116eb6b7 = L.map(
#                 &quot;map_06f2b28d759e8354f2a33898116eb6b7&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ee3c56eccbc27265187ea48f63d44b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_06f2b28d759e8354f2a33898116eb6b7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Define the coordinates we want our markers to be at
CU_Boulder_coords = [40.007153, -105.266930]
East_Campus_coords = [40.013501, -105.251889]
SEEC_coords = [40.009837, -105.241905]

#Add markers to the map
folium.Marker(CU_Boulder_coords, popup = 'CU Boulder').add_to(my_map)
folium.Marker(East_Campus_coords, popup = 'East Campus').add_to(my_map)
folium.Marker(SEEC_coords, popup = 'SEEC Building').add_to(my_map)

#Display the map
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06f2b28d759e8354f2a33898116eb6b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06f2b28d759e8354f2a33898116eb6b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06f2b28d759e8354f2a33898116eb6b7 = L.map(
#                 &quot;map_06f2b28d759e8354f2a33898116eb6b7&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ee3c56eccbc27265187ea48f63d44b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_06f2b28d759e8354f2a33898116eb6b7);
#
#
#             var marker_774dae8f4afe4b58278cc753b305c8d1 = L.marker(
#                 [40.007153, -105.26693],
#                 {}
#             ).addTo(map_06f2b28d759e8354f2a33898116eb6b7);
#
#
#         var popup_f23993058c99c506d3b1b5f538ac753c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_869a0b9426ba74848ae9bc7610ba44dd = $(`&lt;div id=&quot;html_869a0b9426ba74848ae9bc7610ba44dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CU Boulder&lt;/div&gt;`)[0];
#                 popup_f23993058c99c506d3b1b5f538ac753c.setContent(html_869a0b9426ba74848ae9bc7610ba44dd);
#
#
#
#         marker_774dae8f4afe4b58278cc753b305c8d1.bindPopup(popup_f23993058c99c506d3b1b5f538ac753c)
#         ;
#
#
#
#
#             var marker_87c2a2b153bf8563eded0341461489fd = L.marker(
#                 [40.013501, -105.251889],
#                 {}
#             ).addTo(map_06f2b28d759e8354f2a33898116eb6b7);
#
#
#         var popup_bb5b3592f25244fc9a5ee036a854daa8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3914ff844c251980642f9247e3f6360 = $(`&lt;div id=&quot;html_f3914ff844c251980642f9247e3f6360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;East Campus&lt;/div&gt;`)[0];
#                 popup_bb5b3592f25244fc9a5ee036a854daa8.setContent(html_f3914ff844c251980642f9247e3f6360);
#
#
#
#         marker_87c2a2b153bf8563eded0341461489fd.bindPopup(popup_bb5b3592f25244fc9a5ee036a854daa8)
#         ;
#
#
#
#
#             var marker_cded9133d911273ca897dfa81994cf03 = L.marker(
#                 [40.009837, -105.241905],
#                 {}
#             ).addTo(map_06f2b28d759e8354f2a33898116eb6b7);
#
#
#         var popup_e9eeb82e5c0ba1309be0824a21cd0cde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a1fd91dc260f004aee824185bf2f6f5 = $(`&lt;div id=&quot;html_3a1fd91dc260f004aee824185bf2f6f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SEEC Building&lt;/div&gt;`)[0];
#                 popup_e9eeb82e5c0ba1309be0824a21cd0cde.setContent(html_3a1fd91dc260f004aee824185bf2f6f5);
#
#
#
#         marker_cded9133d911273ca897dfa81994cf03.bindPopup(popup_e9eeb82e5c0ba1309be0824a21cd0cde)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Adding a tileset to our map
map_with_tiles = folium.Map(location = boulder_coords, tiles = 'Stamen Toner')
map_with_tiles
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16452aa44b42f3ea1e3e14ce1821abd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16452aa44b42f3ea1e3e14ce1821abd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16452aa44b42f3ea1e3e14ce1821abd1 = L.map(
#                 &quot;map_16452aa44b42f3ea1e3e14ce1821abd1&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3758bf9d48752e974eef3af4d934692f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16452aa44b42f3ea1e3e14ce1821abd1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import requests
import json

def earthquake(f):
    paramss = {"format": "geojson", "starttime": "2023-01-01", 
               "endtime": "2023-12-31", "minmagnitude": 5.0}
    data = requests.get(f, params = paramss)
    data = json.loads(data.text)
    return data

f = r"https://earthquake.usgs.gov/fdsnws/event/1/query?"
quakes = earthquake(f)

# %%
quakes
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1695691847000,
#   'url': 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2018-01-01&endtime=2019-12-31&minmagnitude=6.0',
#   'title': 'USGS Earthquakes',
#   'status': 200,
#   'api': '1.14.0',
#   'count': 279},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': 'southern East Pacific Rise',
#     'time': 1577305212751,
#     'updated': 1584224683040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006r1g',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006r1g&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 572,
#     'net': 'us',
#     'code': '70006r1g',
#     'ids': ',us70006r1g,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 6.072,
#     'rms': 1.15,
#     'gap': 38,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - southern East Pacific Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.8438, -25.2226, 10]},
#    'id': 'us70006r1g'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '203 km W of Port McNeill, Canada',
#     'time': 1577244961626,
#     'updated': 1584224703040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006qt7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006qt7&format=geojson',
#     'felt': 48,
#     'cdi': 4.3,
#     'mmi': 4.233,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 631,
#     'net': 'us',
#     'code': '70006qt7',
#     'ids': ',at00q31tzv,us70006qt7,',
#     'sources': ',at,us,',
#     'types': ',dyfi,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.853,
#     'rms': 0.67,
#     'gap': 77,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 203 km W of Port McNeill, Canada'},
#    'geometry': {'type': 'Point', 'coordinates': [-129.963, 50.6106, 6.58]},
#    'id': 'us70006qt7'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '1 km NE of Lejanías, Colombia',
#     'time': 1577214232492,
#     'updated': 1648340517104,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006qnn',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006qnn&format=geojson',
#     'felt': 247,
#     'cdi': 6.7,
#     'mmi': 6.601,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 815,
#     'net': 'us',
#     'code': '70006qnn',
#     'ids': ',us70006qnn,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.335,
#     'rms': 0.68,
#     'gap': 36,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 1 km NE of Lejanías, Colombia'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.0176, 3.5359, 11]},
#    'id': 'us70006qnn'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '16 km WNW of El Hoyo, Argentina',
#     'time': 1577205813420,
#     'updated': 1614455584130,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006qk4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006qk4&format=geojson',
#     'felt': 5,
#     'cdi': 3.8,
#     'mmi': 1.731,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 556,
#     'net': 'us',
#     'code': '70006qk4',
#     'ids': ',us70006qk4,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 5.13,
#     'rms': 0.93,
#     'gap': 31,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 16 km WNW of El Hoyo, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-63.3857, -26.964, 572.44]},
#    'id': 'us70006qk4'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '189 km W of Port McNeill, Canada',
#     'time': 1577134583555,
#     'updated': 1583603273040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006q96',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006q96&format=geojson',
#     'felt': 18,
#     'cdi': 4.8,
#     'mmi': 4.135,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 562,
#     'net': 'us',
#     'code': '70006q96',
#     'ids': ',at00q2zgtz,ak019ger47o0,us70006q96,',
#     'sources': ',at,ak,us,',
#     'types': ',dyfi,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.042,
#     'rms': 1.05,
#     'gap': 99,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 189 km W of Port McNeill, Canada'},
#    'geometry': {'type': 'Point', 'coordinates': [-129.7573, 50.5169, 10]},
#    'id': 'us70006q96'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '201 km W of Port McNeill, Canada',
#     'time': 1577130583086,
#     'updated': 1583603273040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006q8n',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006q8n&format=geojson',
#     'felt': 13,
#     'cdi': 4.3,
#     'mmi': 4.057,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 559,
#     'net': 'us',
#     'code': '70006q8n',
#     'ids': ',at00q2zdqx,us70006q8n,',
#     'sources': ',at,us,',
#     'types': ',dyfi,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.149,
#     'rms': 1.06,
#     'gap': 100,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 201 km W of Port McNeill, Canada'},
#    'geometry': {'type': 'Point', 'coordinates': [-129.9372, 50.6071, 10]},
#    'id': 'us70006q8n'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': '49 km SW of Jurm, Afghanistan',
#     'time': 1576841992874,
#     'updated': 1594403756914,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006p18',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006p18&format=geojson',
#     'felt': 249,
#     'cdi': 5.6,
#     'mmi': 3.72,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 712,
#     'net': 'us',
#     'code': '70006p18',
#     'ids': ',us70006p18,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.382,
#     'rms': 0.87,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - 49 km SW of Jurm, Afghanistan'},
#    'geometry': {'type': 'Point', 'coordinates': [70.4555, 36.5374, 212]},
#    'id': 'us70006p18'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.8,
#     'place': '7 km S of Magsaysay, Philippines',
#     'time': 1576390311155,
#     'updated': 1690123853929,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006rp9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006rp9&format=geojson',
#     'felt': 135,
#     'cdi': 8.9,
#     'mmi': 7.134,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 832,
#     'net': 'us',
#     'code': '60006rp9',
#     'ids': ',at00q2jijx,pt19349050,us60006rp9,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.546,
#     'rms': 1.05,
#     'gap': 39,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.8 - 7 km S of Magsaysay, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [125.1739, 6.6969, 18]},
#    'id': 'us60006rp9'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '56 km SSE of Sola, Vanuatu',
#     'time': 1576299454937,
#     'updated': 1594402658138,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006rem',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006rem&format=geojson',
#     'felt': 1,
#     'cdi': 8,
#     'mmi': 5.758,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 555,
#     'net': 'us',
#     'code': '60006rem',
#     'ids': ',us60006rem,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.183,
#     'rms': 1.38,
#     'gap': 25,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 56 km SSE of Sola, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [167.7089, -14.3628, 7.51]},
#    'id': 'us60006rem'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '159 km WNW of Hihifo, Tonga',
#     'time': 1575637486540,
#     'updated': 1659979469836,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006n19',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006n19&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': 4.144,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '60006n19',
#     'ids': ',pt19340000,us60006n19,',
#     'sources': ',pt,us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.488,
#     'rms': 0.54,
#     'gap': 47,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 159 km WNW of Hihifo, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-175.1035, -15.2594, 10]},
#    'id': 'us60006n19'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '60 km NNE of Isangel, Vanuatu',
#     'time': 1575490203595,
#     'updated': 1659979267483,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006m2j',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006m2j&format=geojson',
#     'felt': 1,
#     'cdi': 2.7,
#     'mmi': 3.378,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '60006m2j',
#     'ids': ',us60006m2j,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.804,
#     'rms': 0.72,
#     'gap': 20,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 60 km NNE of Isangel, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [169.5748, -19.0677, 266]},
#    'id': 'us60006m2j'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '29 km W of Arica, Chile',
#     'time': 1575362795780,
#     'updated': 1594403735215,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006fh7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006fh7&format=geojson',
#     'felt': 58,
#     'cdi': 4.4,
#     'mmi': 4.968,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 579,
#     'net': 'us',
#     'code': '70006fh7',
#     'ids': ',us70006fh7,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.258,
#     'rms': 1.38,
#     'gap': 82,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 29 km W of Arica, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-70.576, -18.5042, 38]},
#    'id': 'us70006fh7'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '127 km SW of Adak, Alaska',
#     'time': 1575262914821,
#     'updated': 1637121400586,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006f6d',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006f6d&format=geojson',
#     'felt': 1,
#     'cdi': 6.4,
#     'mmi': 4.097,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 554,
#     'net': 'us',
#     'code': '70006f6d',
#     'ids': ',at00q1vcn7,us70006f6d,ak019ffrk3rj,',
#     'sources': ',at,us,ak,',
#     'types': ',dyfi,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.578,
#     'rms': 1.03,
#     'gap': 57,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 127 km SW of Adak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.1001, 51.1867, 28]},
#    'id': 'us70006f6d'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '45 km WNW of Kíssamos, Greece',
#     'time': 1574839422383,
#     'updated': 1582138690040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006dlt',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006dlt&format=geojson',
#     'felt': 108,
#     'cdi': 5.7,
#     'mmi': 4.515,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 615,
#     'net': 'us',
#     'code': '70006dlt',
#     'ids': ',us70006dlt,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.421,
#     'rms': 1.02,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 45 km WNW of Kíssamos, Greece'},
#    'geometry': {'type': 'Point', 'coordinates': [23.2284, 35.7174, 69]},
#    'id': 'us70006dlt'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.4,
#     'place': '15 km WSW of Mamurras, Albania',
#     'time': 1574736852872,
#     'updated': 1610800136303,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006d0m',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006d0m&format=geojson',
#     'felt': 1365,
#     'cdi': 9.1,
#     'mmi': 8.092,
#     'alert': 'orange',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 1910,
#     'net': 'us',
#     'code': '70006d0m',
#     'ids': ',us70006d0m,',
#     'sources': ',us,',
#     'types': ',dyfi,general-text,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 0.936,
#     'rms': 0.61,
#     'gap': 17,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.4 - 15 km WSW of Mamurras, Albania'},
#    'geometry': {'type': 'Point', 'coordinates': [19.5256, 41.5138, 22]},
#    'id': 'us70006d0m'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '95 km SE of Adak, Alaska',
#     'time': 1574556841053,
#     'updated': 1659978040183,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006cb6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006cb6&format=geojson',
#     'felt': 5,
#     'cdi': 2.4,
#     'mmi': 4.303,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 612,
#     'net': 'us',
#     'code': '70006cb6',
#     'ids': ',at00q1g7u3,us70006cb6,ak019f2glesg,',
#     'sources': ',at,us,ak,',
#     'types': ',dyfi,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.658,
#     'rms': 0.95,
#     'gap': 22,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 95 km SE of Adak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-175.5115, 51.3808, 20]},
#    'id': 'us70006cb6'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '241 km SE of Tobi Village, Palau',
#     'time': 1574511075564,
#     'updated': 1581717734040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006c6w',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006c6w&format=geojson',
#     'felt': 0,
#     'cdi': 1,
#     'mmi': 3.221,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 591,
#     'net': 'us',
#     'code': '70006c6w',
#     'ids': ',us70006c6w,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.567,
#     'rms': 0.94,
#     'gap': 25,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 241 km SE of Tobi Village, Palau'},
#    'geometry': {'type': 'Point', 'coordinates': [132.8148, 1.6436, 5]},
#    'id': 'us70006c6w'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '43 km WNW of Sainyabuli, Laos',
#     'time': 1574293843955,
#     'updated': 1594403623441,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006ara',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006ara&format=geojson',
#     'felt': 385,
#     'cdi': 4.9,
#     'mmi': 6.792,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 780,
#     'net': 'us',
#     'code': '70006ara',
#     'ids': ',us70006ara,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.366,
#     'rms': 0.62,
#     'gap': 15,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 43 km WNW of Sainyabuli, Laos'},
#    'geometry': {'type': 'Point', 'coordinates': [101.3558, 19.4533, 10]},
#    'id': 'us70006ara'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '264 km NW of Ozernovskiy, Russia',
#     'time': 1574238368017,
#     'updated': 1581717726040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006a9e',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006a9e&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 611,
#     'net': 'us',
#     'code': '70006a9e',
#     'ids': ',us70006a9e,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.421,
#     'rms': 0.94,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 264 km NW of Ozernovskiy, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [153.6799, 53.128, 496]},
#    'id': 'us70006a9e'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '125 km SW of Puerto Madero, Mexico',
#     'time': 1574224025252,
#     'updated': 1626132386672,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006a6q',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006a6q&format=geojson',
#     'felt': 60,
#     'cdi': 5.5,
#     'mmi': 3.893,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 644,
#     'net': 'us',
#     'code': '70006a6q',
#     'ids': ',us70006a6q,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.365,
#     'rms': 0.79,
#     'gap': 56,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 125 km SW of Puerto Madero, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-93.2068, 13.8859, 15]},
#    'id': 'us70006a6q'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '135 km NW of Ternate, Indonesia',
#     'time': 1573765974753,
#     'updated': 1581106867040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006bpw',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006bpw&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.32,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '60006bpw',
#     'ids': ',us60006bpw,',
#     'sources': ',us,',
#     'types': ',ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.216,
#     'rms': 1.42,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 135 km NW of Ternate, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [126.4161, 1.5361, 23]},
#    'id': 'us60006bpw'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '141 km NW of Ternate, Indonesia',
#     'time': 1573748260578,
#     'updated': 1601703531266,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006bjl',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006bjl&format=geojson',
#     'felt': 41,
#     'cdi': 5.8,
#     'mmi': 6.459,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 799,
#     'net': 'us',
#     'code': '60006bjl',
#     'ids': ',pt19318001,at00q0yvxj,us60006bjl,',
#     'sources': ',pt,at,us,',
#     'types': ',dyfi,finite-fault,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.271,
#     'rms': 1.15,
#     'gap': 11,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 141 km NW of Ternate, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [126.4156, 1.6213, 33]},
#    'id': 'us60006bjl'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '147 km W of Neiafu, Tonga',
#     'time': 1573513408119,
#     'updated': 1580599344040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006adv',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60006adv&format=geojson',
#     'felt': 6,
#     'cdi': 6.8,
#     'mmi': 4.425,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 595,
#     'net': 'us',
#     'code': '60006adv',
#     'ids': ',us60006adv,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 5.152,
#     'rms': 0.75,
#     'gap': 17,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 147 km W of Neiafu, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-175.3675, -18.8625, 10]},
#    'id': 'us60006adv'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.5,
#     'place': 'Fiji region',
#     'time': 1573209884338,
#     'updated': 1580599316040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000693m',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000693m&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 2.458,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 650,
#     'net': 'us',
#     'code': '6000693m',
#     'ids': ',us6000693m,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.765,
#     'rms': 0.83,
#     'gap': 25,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.5 - Fiji region'},
#    'geometry': {'type': 'Point', 'coordinates': [-179.5113, -21.9449, 577]},
#    'id': 'us6000693m'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': 'Vanuatu',
#     'time': 1573000749303,
#     'updated': 1594403555122,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us700063sp',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us700063sp&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.979,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '700063sp',
#     'ids': ',us700063sp,',
#     'sources': ',us,',
#     'types': ',ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.813,
#     'rms': 1.07,
#     'gap': 36,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [167.8086, -13.7208, 10]},
#    'id': 'us700063sp'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '23 km ENE of Sola, Vanuatu',
#     'time': 1572995846588,
#     'updated': 1594403540510,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us700063rx',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us700063rx&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 5.804,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '700063rx',
#     'ids': ',us700063rx,',
#     'sources': ',us,',
#     'types': ',ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.721,
#     'rms': 0.9,
#     'gap': 38,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 23 km ENE of Sola, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [167.7494, -13.7988, 19]},
#    'id': 'us700063rx'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': 'east of the South Sandwich Islands',
#     'time': 1572987121485,
#     'updated': 1580599297040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us700063mh',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us700063mh&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 611,
#     'net': 'us',
#     'code': '700063mh',
#     'ids': ',us700063mh,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 14.063,
#     'rms': 1.42,
#     'gap': 30,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - east of the South Sandwich Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [-9.3217, -57.9236, 10]},
#    'id': 'us700063mh'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.6,
#     'place': '136 km W of Neiafu, Tonga',
#     'time': 1572907412280,
#     'updated': 1641810452839,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000635e',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000635e&format=geojson',
#     'felt': 8,
#     'cdi': 3.8,
#     'mmi': 4.311,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 673,
#     'net': 'us',
#     'code': '7000635e',
#     'ids': ',pt19308001,at00q0gv4p,us7000635e,',
#     'sources': ',pt,at,us,',
#     'types': ',dyfi,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 5.086,
#     'rms': 0.93,
#     'gap': 48,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.6 - 136 km W of Neiafu, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-175.272, -18.5747, 10]},
#    'id': 'us7000635e'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': '29 km SW of Illapel, Chile',
#     'time': 1572904405320,
#     'updated': 1608319321015,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006345',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70006345&format=geojson',
#     'felt': 294,
#     'cdi': 6.1,
#     'mmi': 6.329,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 829,
#     'net': 'us',
#     'code': '70006345',
#     'ids': ',us70006345,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.707,
#     'rms': 1.14,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - 29 km SW of Illapel, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.3753, -31.8362, 53]},
#    'id': 'us70006345'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': 'South Sandwich Islands region',
#     'time': 1572718121113,
#     'updated': 1579377655040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us700062cg',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us700062cg&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.575,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 572,
#     'net': 'us',
#     'code': '700062cg',
#     'ids': ',us700062cg,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 6.073,
#     'rms': 1.3,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-26.2399, -55.735, 8]},
#    'id': 'us700062cg'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.5,
#     'place': '2 km ENE of Bulatukan, Philippines',
#     'time': 1572484279146,
#     'updated': 1681571491357,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us700061e9',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us700061e9&format=geojson',
#     'felt': 93,
#     'cdi': 8.6,
#     'mmi': 6.919,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 730,
#     'net': 'us',
#     'code': '700061e9',
#     'ids': ',at00q07smw,pt19304000,us700061e9,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.428,
#     'rms': 0.76,
#     'gap': 19,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.5 - 2 km ENE of Bulatukan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [125.1782, 6.9098, 10]},
#    'id': 'us700061e9'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.6,
#     'place': '10 km NE of Columbio, Philippines',
#     'time': 1572311083879,
#     'updated': 1690122837649,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000645n',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000645n&format=geojson',
#     'felt': 124,
#     'cdi': 9.1,
#     'mmi': 7.424,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 783,
#     'net': 'us',
#     'code': '6000645n',
#     'ids': ',at00q04301,pt19302000,us6000645n,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.646,
#     'rms': 0.78,
#     'gap': 24,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.6 - 10 km NE of Columbio, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [125.0082, 6.7567, 15]},
#    'id': 'us6000645n'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': 'north of Ascension Island',
#     'time': 1571846894497,
#     'updated': 1578777990040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005xr7',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005xr7&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 611,
#     'net': 'us',
#     'code': '70005xr7',
#     'ids': ',pt19296002,at00pzu4tt,us70005xr7,',
#     'sources': ',pt,at,us,',
#     'types': ',dyfi,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 6.716,
#     'rms': 0.92,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - north of Ascension Island'},
#    'geometry': {'type': 'Point', 'coordinates': [-13.8367, -1.0987, 10]},
#    'id': 'us70005xr7'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.4,
#     'place': '61 km NNE of Isangel, Vanuatu',
#     'time': 1571626349674,
#     'updated': 1578067781040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005wj6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005wj6&format=geojson',
#     'felt': 4,
#     'cdi': 4.2,
#     'mmi': 3.92,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 632,
#     'net': 'us',
#     'code': '70005wj6',
#     'ids': ',us70005wj6,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.806,
#     'rms': 0.91,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.4 - 61 km NNE of Isangel, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [169.4883, -19.0184, 231]},
#    'id': 'us70005wj6'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.4,
#     'place': '7 km ENE of Columbio, Philippines',
#     'time': 1571225826342,
#     'updated': 1690122954903,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005ulm',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005ulm&format=geojson',
#     'felt': 158,
#     'cdi': 8.2,
#     'mmi': 7.552,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 780,
#     'net': 'us',
#     'code': '70005ulm',
#     'ids': ',at00pzgtlv,pt19289000,us70005ulm,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.668,
#     'rms': 0.85,
#     'gap': 33,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.4 - 7 km ENE of Columbio, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [125.007, 6.7147, 16.12]},
#    'id': 'us70005ulm'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': 'southern East Pacific Rise',
#     'time': 1569902167115,
#     'updated': 1577461774040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005p73',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005p73&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '70005p73',
#     'ids': ',us70005p73,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 27.632,
#     'rms': 0.8,
#     'gap': 50,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - southern East Pacific Rise'},
#    'geometry': {'type': 'Point', 'coordinates': [-122.5586, -55.9278, 10]},
#    'id': 'us70005p73'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.7,
#     'place': '70 km WSW of Constitución, Chile',
#     'time': 1569772673236,
#     'updated': 1657774754954,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005nie',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005nie&format=geojson',
#     'felt': 225,
#     'cdi': 6.8,
#     'mmi': 6.33,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 844,
#     'net': 'us',
#     'code': '70005nie',
#     'ids': ',at00pyloci,pt19272001,us70005nie,',
#     'sources': ',at,pt,us,',
#     'types': ',dyfi,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.269,
#     'rms': 0.65,
#     'gap': 98,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.7 - 70 km WSW of Constitución, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-73.163, -35.4758, 11]},
#    'id': 'us70005nie'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '86 km SSE of Pondaguitan, Philippines',
#     'time': 1569722571883,
#     'updated': 1576868615040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005nbb',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005nbb&format=geojson',
#     'felt': 64,
#     'cdi': 6.1,
#     'mmi': 4.232,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 630,
#     'net': 'us',
#     'code': '70005nbb',
#     'ids': ',us70005nbb,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.686,
#     'rms': 1.33,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 86 km SSE of Pondaguitan, Philippines'},
#    'geometry': {'type': 'Point', 'coordinates': [126.5481, 5.6756, 73]},
#    'id': 'us70005nbb'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': 'Kermadec Islands, New Zealand',
#     'time': 1569585902549,
#     'updated': 1576868595040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005mea',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005mea&format=geojson',
#     'felt': 3,
#     'cdi': 4.1,
#     'mmi': 3.769,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 574,
#     'net': 'us',
#     'code': '70005mea',
#     'ids': ',us70005mea,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.926,
#     'rms': 0.86,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - Kermadec Islands, New Zealand'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.8625, -30.1733, 34]},
#    'id': 'us70005mea'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': '30 km W of Villa La Angostura, Argentina',
#     'time': 1569515778155,
#     'updated': 1612644864047,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005lt4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005lt4&format=geojson',
#     'felt': 114,
#     'cdi': 5.4,
#     'mmi': 4.052,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 634,
#     'net': 'us',
#     'code': '70005lt4',
#     'ids': ',us70005lt4,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.445,
#     'rms': 0.79,
#     'gap': 30,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - 30 km W of Villa La Angostura, Argentina'},
#    'geometry': {'type': 'Point', 'coordinates': [-71.9993, -40.8145, 129]},
#    'id': 'us70005lt4'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.5,
#     'place': '33 km NE of Ambon, Indonesia',
#     'time': 1569455203543,
#     'updated': 1594403290911,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005lfd',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005lfd&format=geojson',
#     'felt': 8,
#     'cdi': 7,
#     'mmi': 6.918,
#     'alert': 'yellow',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 656,
#     'net': 'us',
#     'code': '70005lfd',
#     'ids': ',us70005lfd,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.909,
#     'rms': 0.95,
#     'gap': 15,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.5 - 33 km NE of Ambon, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [128.3699, -3.4528, 12.26]},
#    'id': 'us70005lfd'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': 'Southwest Indian Ridge',
#     'time': 1569359987423,
#     'updated': 1576868537040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60005n52',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60005n52&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '60005n52',
#     'ids': ',us60005n52,',
#     'sources': ',us,',
#     'types': ',losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 11.982,
#     'rms': 0.69,
#     'gap': 16,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - Southwest Indian Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [56.2997, -33.8212, 10]},
#    'id': 'us60005n52'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '67 km NNW of San Antonio, Puerto Rico',
#     'time': 1569295420000,
#     'updated': 1679452929311,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019267000',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr2019267000&format=geojson',
#     'felt': 665,
#     'cdi': 5.4,
#     'mmi': 4.244,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 913,
#     'net': 'pr',
#     'code': '2019267000',
#     'ids': ',at00pybg39,pt19267000,us60005mja,pr2019267000,',
#     'sources': ',at,pt,us,pr,',
#     'types': ',dyfi,ground-failure,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': 25,
#     'dmin': 0.6299,
#     'rms': 0.88,
#     'gap': 193,
#     'magType': 'mw',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 67 km NNW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.2701, 19.077, 10]},
#    'id': 'pr2019267000'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': '81 km NNE of Lasem, Indonesia',
#     'time': 1568876793291,
#     'updated': 1575998817040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60005kta',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us60005kta&format=geojson',
#     'felt': 103,
#     'cdi': 3.1,
#     'mmi': 1.475,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 604,
#     'net': 'us',
#     'code': '60005kta',
#     'ids': ',us60005kta,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.698,
#     'rms': 0.97,
#     'gap': 19,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - 81 km NNE of Lasem, Indonesia'},
#    'geometry': {'type': 'Point', 'coordinates': [111.8422, -6.0708, 610]},
#    'id': 'us60005kta'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.6,
#     'place': 'Fiji region',
#     'time': 1567353260392,
#     'updated': 1573838490040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70005axg',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us70005axg&format=geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': 2.61,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 671,
#     'net': 'us',
#     'code': '70005axg',
#     'ids': ',pt19244000,at00px5tik,us70005axg,',
#     'sources': ',pt,at,us,',
#     'types': ',dyfi,impact-link,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.121,
#     'rms': 1.02,
#     'gap': 19,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.6 - Fiji region'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.5701, -20.3641, 591]},
#    'id': 'us70005axg'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '285 km W of Bandon, Oregon',
#     'time': 1567091278646,
#     'updated': 1628960165720,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us700059qh',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us700059qh&format=geojson',
#     'felt': 796,
#     'cdi': 5,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1009,
#     'net': 'us',
#     'code': '700059qh',
#     'ids': ',at00px07dc,us700059qh,',
#     'sources': ',at,us,',
#     'types': ',dyfi,general-text,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.678,
#     'rms': 1.17,
#     'gap': 31,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 285 km W of Bandon, Oregon'},
#    'geometry': {'type': 'Point', 'coordinates': [-127.8817, 43.5425, 10]},
#    'id': 'us700059qh'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.6,
#     'place': 'South Sandwich Islands region',
#     'time': 1566950119187,
#     'updated': 1573838339040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us700058yy',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us700058yy&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 4.012,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 670,
#     'net': 'us',
#     'code': '700058yy',
#     'ids': ',at00pwx6gi,pt19240050,us700058yy,',
#     'sources': ',at,pt,us,',
#     'types': ',impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 12.896,
#     'rms': 0.91,
#     'gap': 19,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.6 - South Sandwich Islands region'},
#    'geometry': {'type': 'Point', 'coordinates': [-26.5801, -60.2152, 16]},
#    'id': 'us700058yy'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '61 km SW of Sola, Vanuatu',
#     'time': 1566661887119,
#     'updated': 1573251226040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us700057v4',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us700057v4&format=geojson',
#     'felt': 5,
#     'cdi': 3.4,
#     'mmi': 4.359,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 556,
#     'net': 'us',
#     'code': '700057v4',
#     'ids': ',us700057v4,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.131,
#     'rms': 1.19,
#     'gap': 26,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 61 km SW of Sola, Vanuatu'},
#    'geometry': {'type': 'Point', 'coordinates': [167.1897, -14.309, 115]},
#    'id': 'us700057v4'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': 'western Indian-Antarctic Ridge',
#     'time': 1566397705652,
#     'updated': 1573251217040,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us600057xt',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us600057xt&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '600057xt',
#     'ids': ',us600057xt,',
#     'sources': ',us,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 9.234,
#     'rms': 0.66,
#     'gap': 67,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - western Indian-Antarctic Ridge'},
#    'geometry': {'type': 'Point', 'coordinates': [139.324, -50.3302, 10]},
#    'id': 'us600057xt'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': 'Santa Cruz Islands',
#     'time': 1566306232633,
#     'updated': 1594402469511,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us600057ee',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us600057ee&format=geojson',
#     'felt': 1,
#     'cdi': 4,
#     'mmi': 4.783,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '600057ee',
#     'ids': ',us600057ee,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 4.15,
#     'rms': 0.99,
#     'gap': 42,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - Santa Cruz Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [166.2912, -11.3683, 37]},
#    'id': 'us600057ee'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '61 km ENE of Namie, Japan',
#     'time': 1564914183726,
#     'updated': 1594402399457,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us600050if',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us600050if&format=geojson',
#     'felt': 323,
#     'cdi': 7.1,
#     'mmi': 4.86,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 840,
#     'net': 'us',
#     'code': '600050if',
#     'ids': ',us600050if,',
#     'sources': ',us,',
#     'types': ',dyfi,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.653,
#     'rms': 0.78,
#     'gap': 32,
#     'magType': 'mww',
#     'type': 'earthquake',
# ...
#     'nst': None,
#     'dmin': 0.142,
#     'rms': 1.23,
#     'gap': 82,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.2 - 4 km S of Pinotepa de Don Luis, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-97.9787, 16.3855, 22]},
#    'id': 'us2000d3km'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '154 km SE of San Jose Village, Northern Mariana Islands',
#     'time': 1518390855080,
#     'updated': 1651604573322,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000d0p1',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000d0p1&format=geojson',
#     'felt': 25,
#     'cdi': 3.6,
#     'mmi': 3.61,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 563,
#     'net': 'us',
#     'code': '2000d0p1',
#     'ids': ',pt18042001,us2000d0p1,iscgem611835974,',
#     'sources': ',pt,us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.542,
#     'rms': 0.73,
#     'gap': 15,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 154 km SE of San Jose Village, Northern Mariana Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [146.4377, 13.8205, 10]},
#    'id': 'us2000d0p1'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '215 km E of Levuka, Fiji',
#     'time': 1518176636760,
#     'updated': 1651603731157,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000czgc',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000czgc&format=geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': 2.29,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '2000czgc',
#     'ids': ',us2000czgc,iscgem611722765,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 7.704,
#     'rms': 0.9,
#     'gap': 35,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 215 km E of Levuka, Fiji'},
#    'geometry': {'type': 'Point', 'coordinates': [-178.6605, -17.8709, 556.91]},
#    'id': 'us2000czgc'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.4,
#     'place': '18 km NNE of Hualien City, Taiwan',
#     'time': 1517932243320,
#     'updated': 1651607789191,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000chhc',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000chhc&format=geojson',
#     'felt': 305,
#     'cdi': 7.8,
#     'mmi': 7.648,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 868,
#     'net': 'us',
#     'code': '1000chhc',
#     'ids': ',us1000chhc,iscgem616640792,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,general-text,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 0.07,
#     'rms': 0.91,
#     'gap': 34,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.4 - 18 km NNE of Hualien City, Taiwan'},
#    'geometry': {'type': 'Point', 'coordinates': [121.6586, 24.1338, 17]},
#    'id': 'us1000chhc'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.1,
#     'place': '22 km NNE of Hualien City, Taiwan',
#     'time': 1517752601950,
#     'updated': 1651604570693,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000cfn6',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000cfn6&format=geojson',
#     'felt': 306,
#     'cdi': 5.4,
#     'mmi': 5.873,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 738,
#     'net': 'us',
#     'code': '1000cfn6',
#     'ids': ',us1000cfn6,iscgem611835901,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.104,
#     'rms': 0.87,
#     'gap': 30,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.1 - 22 km NNE of Hualien City, Taiwan'},
#    'geometry': {'type': 'Point', 'coordinates': [121.7078, 24.1572, 12]},
#    'id': 'us1000cfn6'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '254 km SSE of Alo, Wallis and Futuna',
#     'time': 1517483150630,
#     'updated': 1651603616864,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000cdn0',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000cdn0&format=geojson',
#     'felt': 3,
#     'cdi': 3.4,
#     'mmi': 3.66,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 555,
#     'net': 'us',
#     'code': '1000cdn0',
#     'ids': ',us1000cdn0,iscgem611669034,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 6.068,
#     'rms': 1.14,
#     'gap': 56,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 254 km SSE of Alo, Wallis and Futuna'},
#    'geometry': {'type': 'Point', 'coordinates': [-177.4612, -16.5186, 10]},
#    'id': 'us1000cdn0'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '37 km S of Jurm, Afghanistan',
#     'time': 1517382420290,
#     'updated': 1659915955672,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000crmu',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000crmu&format=geojson',
#     'felt': 313,
#     'cdi': 6.4,
#     'mmi': 3.922,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 792,
#     'net': 'us',
#     'code': '2000crmu',
#     'ids': ',us2000crmu,iscgem611835880,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.637,
#     'rms': 0.86,
#     'gap': 17,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 37 km S of Jurm, Afghanistan'},
#    'geometry': {'type': 'Point', 'coordinates': [70.8507, 36.5261, 193.73]},
#    'id': 'us2000crmu'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.6,
#     'place': 'southwest of Africa',
#     'time': 1517155383970,
#     'updated': 1651604565612,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cqnn',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cqnn&format=geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 0,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 670,
#     'net': 'us',
#     'code': '2000cqnn',
#     'ids': ',us2000cqnn,pt18028001,at00p39wl1,iscgem611835852,',
#     'sources': ',us,pt,at,iscgem,',
#     'types': ',impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 19.475,
#     'rms': 0.61,
#     'gap': 27,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.6 - southwest of Africa'},
#    'geometry': {'type': 'Point', 'coordinates': [9.6842, -53.0623, 10]},
#    'id': 'us2000cqnn'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '188 km N of Madang, Papua New Guinea',
#     'time': 1517006877760,
#     'updated': 1651604562838,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cq5t',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cq5t&format=geojson',
#     'felt': 43,
#     'cdi': 9,
#     'mmi': 4.07,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 649,
#     'net': 'us',
#     'code': '2000cq5t',
#     'ids': ',us2000cq5t,iscgem611835835,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.105,
#     'rms': 0.7,
#     'gap': 18,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 188 km N of Madang, Papua New Guinea'},
#    'geometry': {'type': 'Point', 'coordinates': [145.8477, -3.5138, 10]},
#    'id': 'us2000cq5t'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.2,
#     'place': '259 km ESE of Ust’-Kamchatsk Staryy, Russia',
#     'time': 1516846234820,
#     'updated': 1651603548386,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cp4y',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cp4y&format=geojson',
#     'felt': 6,
#     'cdi': 3.8,
#     'mmi': 5.57,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 594,
#     'net': 'us',
#     'code': '2000cp4y',
#     'ids': ',us2000cp4y,iscgem611658170,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 5.219,
#     'rms': 0.6,
#     'gap': 35,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.2 - 259 km ESE of Ust’-Kamchatsk Staryy, Russia'},
#    'geometry': {'type': 'Point', 'coordinates': [166.4497, 55.5423, 11.15]},
#    'id': 'us2000cp4y'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '99 km ENE of Misawa, Japan',
#     'time': 1516791079090,
#     'updated': 1651608184447,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cnnl',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cnnl&format=geojson',
#     'felt': 57,
#     'cdi': 5.3,
#     'mmi': 4.57,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 641,
#     'net': 'us',
#     'code': '2000cnnl',
#     'ids': ',us2000cnnl,iscgem618237460,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.061,
#     'rms': 0.88,
#     'gap': 51,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 99 km ENE of Misawa, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [142.4323, 41.1034, 31]},
#    'id': 'us2000cnnl'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.9,
#     'place': '261 km SE of Chiniak, Alaska',
#     'time': 1516699900890,
#     'updated': 1691767354958,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cmy3',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cmy3&format=geojson',
#     'felt': 2385,
#     'cdi': 9.1,
#     'mmi': 4.303,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1870,
#     'net': 'us',
#     'code': '2000cmy3',
#     'ids': ',ak18173527,us2000cmy3,at00p3054t,pt18023001,ak018126wm5v,iscgem611653794,ak18173519,',
#     'sources': ',ak,us,at,pt,ak,iscgem,ak,',
#     'types': ',associate,dyfi,finite-fault,general-link,general-text,ground-failure,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,trump-origin,',
#     'nst': None,
#     'dmin': 2.585,
#     'rms': 0.77,
#     'gap': 30,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.9 - 261 km SE of Chiniak, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.1658, 56.0039, 14.06]},
#    'id': 'us2000cmy3'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '100 km ESE of Arica, Chile',
#     'time': 1516496802710,
#     'updated': 1651604558776,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cm0f',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cm0f&format=geojson',
#     'felt': 64,
#     'cdi': 5.5,
#     'mmi': 4.867,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 646,
#     'net': 'us',
#     'code': '2000cm0f',
#     'ids': ',us2000cm0f,iscgem611835791,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 0.545,
#     'rms': 1.41,
#     'gap': 15,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 100 km ESE of Arica, Chile'},
#    'geometry': {'type': 'Point', 'coordinates': [-69.4445, -18.8806, 116]},
#    'id': 'us2000cm0f'},
#   {'type': 'Feature',
#    'properties': {'mag': 6.3,
#     'place': '79 km NNE of Loreto, Mexico',
#     'time': 1516378664720,
#     'updated': 1680360434196,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cl83',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cl83&format=geojson',
#     'felt': 106,
#     'cdi': 6,
#     'mmi': 5.049,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 674,
#     'net': 'us',
#     'code': '2000cl83',
#     'ids': ',at00p2t99m,us2000cl83,iscgem611835770,',
#     'sources': ',at,us,iscgem,',
#     'types': ',dyfi,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 1.214,
#     'rms': 1.45,
#     'gap': 109,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.3 - 79 km NNE of Loreto, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-111.0785, 26.6862, 10]},
#    'id': 'us2000cl83'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.1,
#     'place': '37 km W of Atiquipa, Peru',
#     'time': 1515921525540,
#     'updated': 1651603510126,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cjfy',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cjfy&format=geojson',
#     'felt': 352,
#     'cdi': 8.5,
#     'mmi': 6.946,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1075,
#     'net': 'us',
#     'code': '2000cjfy',
#     'ids': ',at00p2jgj9,pt18014000,us2000cjfy,iscgem611648221,',
#     'sources': ',at,pt,us,iscgem,',
#     'types': ',dyfi,finite-fault,general-text,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 4.29,
#     'rms': 1.2,
#     'gap': 23,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.1 - 37 km W of Atiquipa, Peru'},
#    'geometry': {'type': 'Point', 'coordinates': [-74.7092, -15.7675, 39]},
#    'id': 'us2000cjfy'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '40 km WSW of Pyu, Myanmar',
#     'time': 1515695184240,
#     'updated': 1651608007010,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us2000cifa',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us2000cifa&format=geojson',
#     'felt': 173,
#     'cdi': 9.1,
#     'mmi': 6.633,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 711,
#     'net': 'us',
#     'code': '2000cifa',
#     'ids': ',us2000cifa,iscgem617446172,',
#     'sources': ',us,iscgem,',
#     'types': ',dyfi,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 2.759,
#     'rms': 1.01,
#     'gap': 29,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 40 km WSW of Pyu, Myanmar'},
#    'geometry': {'type': 'Point', 'coordinates': [96.0717, 18.3719, 9]},
#    'id': 'us2000cifa'},
#   {'type': 'Feature',
#    'properties': {'mag': 7.5,
#     'place': '203 km NNE of Barra Patuca, Honduras',
#     'time': 1515552693290,
#     'updated': 1651603488043,
#     'tz': None,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us1000c2zy',
#     'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us1000c2zy&format=geojson',
#     'felt': 913,
#     'cdi': 8.3,
#     'mmi': 5.425,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 1623,
#     'net': 'us',
#     'code': '1000c2zy',
#     'ids': ',at00p2bjxw,pt18010000,us1000c2zy,iscgem611634051,',
#     'sources': ',at,pt,us,iscgem,',
#     'types': ',dyfi,finite-fault,general-link,general-text,impact-link,impact-text,losspager,moment-tensor,origin,phase-data,poster,shakemap,',
#     'nst': None,
#     'dmin': 4.581,
#     'rms': 0.82,
#     'gap': 12,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 7.5 - 203 km NNE of Barra Patuca, Honduras'},
#    'geometry': {'type': 'Point', 'coordinates': [-83.52, 17.4825, 19]},
#    'id': 'us1000c2zy'}],
#  'bbox': [-179.5113, -61.2867, 4.99, 179.3502, 71.6312, 670.81]}

# %%
m = folium.Map([43, -100], zoom_start=4)

folium.GeoJson(quakes,
      #  marker=folium.Circle(radius=100, fill_color="orange", fill_opacity=0.4, color="black", weight=1),
        marker=folium.CircleMarker(radius=5),
               style_function=lambda x: {
      #  "fillColor": colors[x['properties']['service_level']],
        "color": x['properties']['alert'],
        "radius": (x['properties']['mag']),                  
        }
     ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9292a891a4edf71f63eee269bd7899bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9292a891a4edf71f63eee269bd7899bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9292a891a4edf71f63eee269bd7899bb = L.map(
#                 &quot;map_9292a891a4edf71f63eee269bd7899bb&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f37da10ab5e35ff5523a7bda92f8496c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9292a891a4edf71f63eee269bd7899bb);
#
#
#         function geo_json_03c3f001537f21fcbb88ca4ff4658d0f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;us7000kxr1&quot;: case &quot;us7000kxnj&quot;: case &quot;us7000kwdw&quot;: case &quot;us7000kwd8&quot;: case &quot;us7000kvyp&quot;: case &quot;us7000kvw0&quot;: case &quot;us7000kvva&quot;: case &quot;us7000kvnq&quot;: case &quot;us7000kvfm&quot;: case &quot;us7000kvf0&quot;: case &quot;us7000kv78&quot;: case &quot;us7000kuyi&quot;: case &quot;us7000kuck&quot;: case &quot;us7000ku0l&quot;: case &quot;us7000ktvf&quot;: case &quot;us7000ktfe&quot;: case &quot;us7000ktee&quot;: case &quot;us7000kt6h&quot;: case &quot;us7000kt06&quot;: case &quot;us7000kslp&quot;: case &quot;us7000ksgy&quot;: case &quot;us7000ks64&quot;: case &quot;us7000ktfx&quot;: case &quot;us7000ksfb&quot;: case &quot;us7000kr5r&quot;: case &quot;us7000kr0x&quot;: case &quot;us7000kqdh&quot;: case &quot;us7000kp2a&quot;: case &quot;us7000knkw&quot;: case &quot;us6000kznp&quot;: case &quot;us6000kz0u&quot;: case &quot;us6000ky9w&quot;: case &quot;us6000ky52&quot;: case &quot;us6000kxnn&quot;: case &quot;us6000kw09&quot;: case &quot;us6000kvt9&quot;: case &quot;us6000kvqq&quot;: case &quot;us7000ki9d&quot;: case &quot;us7000ki52&quot;: case &quot;us7000khss&quot;: case &quot;us7000kgsp&quot;: case &quot;us7000kg5l&quot;: case &quot;us7000kffm&quot;: case &quot;us7000kevb&quot;: case &quot;us6000kr69&quot;: case &quot;us6000kr0n&quot;: case &quot;us6000kqqq&quot;: case &quot;us6000kqck&quot;: case &quot;us7000kff3&quot;: case &quot;us6000kpwp&quot;: case &quot;us6000kppk&quot;: case &quot;us6000knrs&quot;: case &quot;us7000kai7&quot;: case &quot;us7000kaf3&quot;: case &quot;us7000k9sj&quot;: case &quot;us7000k9qk&quot;: case &quot;us7000k9eb&quot;: case &quot;us7000k9d9&quot;: case &quot;us7000k9d7&quot;: case &quot;us7000k9bu&quot;: case &quot;us7000k99p&quot;: case &quot;us7000k8vx&quot;: case &quot;us7000k6yf&quot;: case &quot;us7000k6rl&quot;: case &quot;us7000k6qq&quot;: case &quot;us7000k67k&quot;: case &quot;us7000k603&quot;: case &quot;us7000k5ux&quot;: case &quot;us7000k5p3&quot;: case &quot;us7000k5nz&quot;: case &quot;us7000k5eb&quot;: case &quot;us7000k54v&quot;: case &quot;us7000k4qj&quot;: case &quot;us7000k4na&quot;: case &quot;us7000k4m6&quot;: case &quot;us7000k3wu&quot;: case &quot;us7000k39d&quot;: case &quot;us7000k36l&quot;: case &quot;us6000kdu2&quot;: case &quot;us6000kdpx&quot;: case &quot;us6000kdif&quot;: case &quot;us6000kdi1&quot;: case &quot;us6000kdg5&quot;: case &quot;us6000kde0&quot;: case &quot;us6000kddt&quot;: case &quot;us6000kdav&quot;: case &quot;us6000kd4f&quot;: case &quot;us6000kd1x&quot;: case &quot;us6000kd23&quot;: case &quot;us6000kcxi&quot;: case &quot;us6000kbvu&quot;: case &quot;us6000kbtw&quot;: case &quot;us6000kasa&quot;: case &quot;us6000kalp&quot;: case &quot;us6000kadq&quot;: case &quot;us6000ka29&quot;: case &quot;us6000ka1t&quot;: case &quot;us6000k9wx&quot;: case &quot;us6000k9k8&quot;: case &quot;us7000jxi0&quot;: case &quot;us7000jxc1&quot;: case &quot;us7000jxab&quot;: case &quot;us7000jx9j&quot;: case &quot;us7000jx29&quot;: case &quot;us7000jwdq&quot;: case &quot;us7000jw5x&quot;: case &quot;us7000jw4k&quot;: case &quot;us7000jw42&quot;: case &quot;us7000jw1k&quot;: case &quot;us7000jwnm&quot;: case &quot;us6000k6hc&quot;: case &quot;us6000k5ky&quot;: case &quot;us6000k51u&quot;: case &quot;us6000k4is&quot;: case &quot;us6000k43z&quot;: case &quot;us6000k3ds&quot;: case &quot;us6000k377&quot;: case &quot;us6000k36r&quot;: case &quot;us6000k2xs&quot;: case &quot;us6000k2b0&quot;: case &quot;us6000k2ae&quot;: case &quot;us6000k22u&quot;: case &quot;us6000k1ty&quot;: case &quot;us6000k1d6&quot;: case &quot;us6000k091&quot;: case &quot;us7000jmuw&quot;: case &quot;us7000jmuh&quot;: case &quot;us7000jm3e&quot;: case &quot;us7000jm0w&quot;: case &quot;us7000jlef&quot;: case &quot;us7000jkjc&quot;: case &quot;us7000jlq1&quot;: case &quot;us7000jje1&quot;: case &quot;us7000jj97&quot;: case &quot;us7000jiyr&quot;: case &quot;us7000jikg&quot;: case &quot;us7000jhj3&q
